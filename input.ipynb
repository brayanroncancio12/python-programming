# %%
Name = input("What is your name? ")
age = input("What is your age? ")

print('Hello {name}, you are {age} years old '.format(name=Name, age=age))
# Out:
# Hello brayan, you are 26 years old
